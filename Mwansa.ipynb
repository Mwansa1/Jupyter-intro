# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('inequality-before-and-after-taxes-and-transfers-Thewissen-et-al-data (1).csv')

data = data.sort_values(by=['Year'])
# data = data.drop(labels= 'Year', axis =1)
population = data[data.Entity == 'pop']

period = data[data.Entity == 'Entity']
country = data[data.Entity == 'Code']

population_data = pd.concat([population,period,country])
data.plot(x="Year", y="pop", kind="line")
