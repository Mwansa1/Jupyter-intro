# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('number-of-described-species.csv')
names = data[["Entity"]]
number_of_species= data[["Number of described species"]]


df = pd.DataFrame(data={'Species': [names],'Number of described species':[number_of_species]})
data.plot(x="Entity", y="Number of described species", kind="bar")
# print(names)
# print(number_of_species)
